# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv(
    "../data/raw/AAPL.csv",
    index_col=0,
    parse_dates=True
)

df.head()
# Out:
# C:\Users\Varun\AppData\Local\Temp\ipykernel_27844\3601658405.py:4: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df = pd.read_csv(
#                      Adj Close               Close                High  \
# Price
# Ticker                    AAPL                AAPL                AAPL
# Date                       NaN                 NaN                 NaN
# 2015-01-02  24.237558364868164  27.332500457763672  27.860000610351562
# 2015-01-05  23.554738998413086             26.5625  27.162500381469727
# 2015-01-06  23.556957244873047  26.565000534057617  26.857500076293945
#
#                            Low                Open     Volume
# Price
# Ticker                    AAPL                AAPL       AAPL
# Date                       NaN                 NaN        NaN
# 2015-01-02  26.837499618530273   27.84749984741211  212818400
# ...

# %%
df.isna().sum()
# Out:
# Adj Close    1
# Close        1
# High         1
# Low          1
# Open         1
# Volume       1
# dtype: int64

# %%
df.columns
# Out:
# Index(['Adj Close', 'Close', 'High', 'Low', 'Open', 'Volume'], dtype='object')

# %%
import matplotlib.pyplot as plt

df["Adj Close"].astype(float).plot(figsize=(10, 4))
plt.title("AAPL Adjusted Close")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[6], line 3
#       1 import matplotlib.pyplot as plt
# ----> 3 df["Adj Close"].astype(float).plot(figsize=(10, 4))
#       4 plt.title("AAPL Adjusted Close")
#       5 plt.show()
#
# File c:\Users\Varun\OneDrive\Desktop\ptre\venv\Lib\site-packages\pandas\core\generic.py:6665, in NDFrame.astype(self, dtype, copy, errors)
#    6659     results = [
#    6660         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6661     ]
#    6663 else:
#    6664     # else, only a single dtype is given
# -> 6665     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6666     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6667     return res.__finalize__(self, method="astype")
#
# ...

# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/AAPL_clean.csv",
    index_col=0,
    parse_dates=True
)

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2757 entries, 2015-01-02 to Ticker
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   open       2757 non-null   float64
#  1   high       2757 non-null   float64
#  2   low        2757 non-null   float64
#  3   close      2757 non-null   float64
#  4   adj_close  2757 non-null   float64
#  5   volume     2757 non-null   float64
# dtypes: float64(6)
# memory usage: 150.8+ KB

# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/features/AAPL_features.csv",
    index_col=0,
    parse_dates=True
)


df.shape
# Out:
# (2679, 40)

# %%
import pandas as pd

df = pd.read_csv(
    "../data/processed/features/AAPL_features.csv",
    index_col=0,
    parse_dates=True
)

df.dtypes
# Out:
# ret_1d                   float64
# ret_3d                   float64
# ret_5d                   float64
# ret_10d                  float64
# log_ret_1d               float64
# log_ret_5d               float64
# cum_ret_5d               float64
# cum_ret_10d              float64
# vol_5d                   float64
# vol_10d                  float64
# vol_20d                  float64
# vol_ratio_5_20           float64
# vol_ratio_10_20          float64
# hl_vol_5d                float64
# hl_vol_10d               float64
# rsi_14                   float64
# rsi_divergence           float64
# dmi_spread               float64
# roc_5d                   float64
# roc_10d                  float64
# mom_slope_5d             float64
# mom_slope_10d            float64
# dist_sma_20              float64
# dist_sma_50              float64
# trend_alignment          float64
# dist_ema_20              float64
# dist_ema_50              float64
# price_range_pos_20       float64
# ...

# %%
import os
os.chdir(r"C:\Users\Varun\OneDrive\Desktop\ptre")

# %%
print(os.getcwd())
# Out:
# C:\Users\Varun\OneDrive\Desktop\ptre

# %%
X = pd.read_csv("data/processed/features/AAPL_features.csv", index_col=0)
y = pd.read_csv("data/processed/labels/AAPL_labels.csv", index_col=0)

# %%
print("FEATURE index sample:")
print(X.index[:10])

print("\nLABEL index sample:")
print(y.index[:10])

print("\nFeature index dtype:", X.index.dtype)
print("Label index dtype:", y.index.dtype)

X_idx = pd.to_datetime(X.index, errors="coerce")
y_idx = pd.to_datetime(y.index, errors="coerce")

print("\nIntersection length:", len(X_idx.intersection(y_idx)))
# Out:
# FEATURE index sample:
# Index(['2015-04-27', '2015-04-28', '2015-04-29', '2015-04-30', '2015-05-01',
#        '2015-05-04', '2015-05-05', '2015-05-06', '2015-05-07', '2015-05-08'],
#       dtype='object', name='Price')
#
# LABEL index sample:
# Index(['2015-04-27', '2015-04-28', '2015-04-29', '2015-04-30', '2015-05-01',
#        '2015-05-04', '2015-05-05', '2015-05-06', '2015-05-07', '2015-05-08'],
#       dtype='object', name='Price')
#
# Feature index dtype: object
# Label index dtype: object
#
# Intersection length: 2669

# %%
print(os.getcwd())
# Out:
# C:\Users\Varun\OneDrive\Desktop\ptre

# %%
from src.models.train_baseline import load_data

# %%
df = load_data("AAPL")
print(df.shape)
print(df.index.dtype)
df.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 df = load_data("AAPL")
#       2 print(df.shape)
#       3 print(df.index.dtype)
#
# File ~\OneDrive\Desktop\ptre\src\models\train_baseline.py:26, in load_data(ticker)
#      20 y = pd.read_csv(
#      21     LABEL_DIR / f"{ticker}_labels.csv",
#      22     index_col=0
#      23 )["label"]
#      25 # 🔒 FORCE proper datetime index (THE FIX)
# ---> 26 X.index = pd.to_datetime(X.index, format="%Y-%m-%d")
#      27 y.index = pd.to_datetime(y.index, format="%Y-%m-%d")
#      29 # Ensure sorted
#
# File c:\Users\Varun\OneDrive\Desktop\ptre\venv\Lib\site-packages\pandas\core\tools\datetimes.py:1081, in to_datetime(arg, errors, dayfirst, yearfirst, utc, format, exact, unit, infer_datetime_format, origin, cache)
#    1079         result = _convert_and_box_cache(arg, cache_array, name=arg.name)
# ...
